# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 25)

# %%
emails_df = pd.read_csv('data_files/Emails.csv')
emails_df.columns
# Out:
# Index([u'Id', u'DocNumber', u'MetadataSubject', u'MetadataTo', u'MetadataFrom',
#        u'SenderPersonId', u'MetadataDateSent', u'MetadataDateReleased',
#        u'MetadataPdfLink', u'MetadataCaseNumber', u'MetadataDocumentClass',
#        u'ExtractedSubject', u'ExtractedTo', u'ExtractedFrom', u'ExtractedCc',
#        u'ExtractedDateSent', u'ExtractedCaseNumber', u'ExtractedDocNumber',
#        u'ExtractedDateReleased', u'ExtractedReleaseInPartOrFull',
#        u'ExtractedBodyText', u'RawText'],
#       dtype='object')

# %%
persons_df = pd.read_csv('data_files/Persons.csv')
persons_df
# Out:
#       Id                           Name
# 0      1                 111th Congress
# 1      2   AGNA USEMB Kabul Afghanistan
# 2      3                             AP
# 3      4                       ASUNCION
# 4      5                           Alec
# 5      6                     Alex Dupuy
# 6      7  American Beverage Association
# 7      8                  Andrew Mayock
# 8      9                 Andrew Shapiro
# 9     10           Anne-Marie Slaughter
# 10    11                   Anthony Lake
# 11    12              Arturo Valenzuela
# 12    13                    Ban Ki-moon
# 13    14                   Barack Obama
# 14    15               Barbara Mikulski
# 15    16                  Betsy Ebeling
# 16    17                   Bill Clinton
# 17    18                      Biography
# 18    19                   Bonnie Klehr
# 19    20                Brian Greenspun
# 20    21                  Burns Strider
# 21    22              Capricia Marshall
# ...

# %%
aliases_df = pd.read_csv('data_files/Aliases.csv')
aliases_df
# Out:
#       Id                          Alias  PersonId
# 0      1                 111th congress         1
# 1      2   agna usemb kabul afghanistan         2
# 2      3                             ap         3
# 3      4                       asuncion         4
# 4      5                           alec         5
# 5      6                     dupuy alex         6
# 6      7  american beverage association         7
# 7      8                  mayock andrew         8
# 8      9               shapiro andrew j         9
# 9     10             shapiroa@state.gov         9
# 10    11             slaughter annmarie        10
# 11    12           slaughter anne marie        10
# 12    13            slaughter annemarie        10
# 13    14           slaughtera@state.gov        10
# 14    15                   lake anthony        11
# 15    16            valenzuela arturo a        12
# 16    17         valenzuelaaa@state.gov        12
# 17    18                     kimoon ban        13
# ...

# %%
email_receivers_df = pd.read_csv('data_files/EmailReceivers.csv')
email_receivers_df
# Out:
#         Id  EmailId  PersonId
# 0        1        1        80
# 1        2        2        80
# 2        3        3       228
# 3        4        3        80
# 4        5        4        80
# 5        6        5        81
# 6        7        6       185
# 7        8        7        80
# 8        9        8        81
# 9       10        9        80
# 10      11       10        80
# 11      12       11        80
# 12      13       12        80
# 13      14       13        80
# 14      15       14        80
# 15      16       15        80
# 16      17       16        80
# 17      18       17        80
# 18      19       17        32
# 19      20       17       229
# 20      21       17       170
# 21      22       17        87
# 22      23       18        80
# 23      24       18        32
# 24      25       18       230
# 25      26       18       231
# 26      27       19        80
# 27      28       20       213
# 28      29       21        87
# 29      30       22       185
# ...

# %%
emails_df.MetadataTo.value_counts()

#len(emails_df.MetadataTo.value_counts())
# Out:
# H                                     5370
# abedinh@state.gov                      337
# millscd@state.gov                      311
# sullivanjj@state.gov                   297
# JilotyLC@state.gov                     231
# ValmoroLJ@state.gov                    141
# Abedin, Huma                            77
# preines                                 58
# sbwhoeop                                48
# Hillary                                 43
# cheryl.mills                            38
# hanleymr@state.gov                      34
# H2                                      33
# Mills, Cheryl D                         32
# vermarr@state.gov                       30
# slaughtera@state.gov                    29
# Russorv@state.gov                       26
# Sullivan, Jacob J                       24
# muscatinel@state.gov                    18
# Flores, Oscar                           18
# balderstonkm@state.gov                  16
# AbedinH@state.gov                       15
# ...

# %%
emails_df.MetadataFrom.value_counts()
# Out:
# H                                   1906
# Abedin, Huma                        1380
# Mills, Cheryl D                     1146
# Sullivan, Jacob J                    750
# sbwhoeop                             316
# Jiloty, Lauren C                     302
# Valmoro, Lona J                      146
# Slaughter, Anne-Marie                127
# Verma, Richard R                     115
# PIR                                  108
# McHale, Judith A                      73
# hrod17@clintonemail.com               71
# Muscatine, Lissa                      70
# MillsCD@state.gov                     64
# Verveer, Melanne S                    59
# AbedinH@state.gov                     49
# Mills, Cheryl                         46
# cheryl.mills                          44
# Sid                                   43
# jake.sullivan                         38
# Sullivan, Jake                        37
# Talbott, Strobe                       36
# Reines, Philippe I                    34
# ...

# %%
# way to compare extractedto extracted from metadatato
