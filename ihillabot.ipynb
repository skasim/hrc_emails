# %%
import json

# %%
filename = "tbot_emails.txt"

with open(filename, "r") as f:
    data = f.read()

# %%
for x in data:
    print x
# Out:
# "
# F
# o
# l
# l
# o
# w
#
# U
# p
#
# F
# l
# a
# g
# :
#
# F
# o
# l
# l
# o
# w
#
# u
# p
# \
# n
# F
# l
# a
# g
#
# S
# t
# a
# t
# u
# s
# :
#
# F
# l
# a
# g
# g
# e
# d
# \
# n
# M
# o
# r
# e
#
# i
# n
# f
# o
# ,
# \
# n
# "
# "
# B
# o
# t
# h
#
# G
# a
# t
# e
# s
#
# a
# n
# d
#
# I
#
# s
# a
# i
# d
#
# t
# h
# e
#
# s
# a
# m
# e
#
# o
# n
#
# t
# h
# e
#
# S
# u
# n
# d
# a
# y
#
# s
# h
# o
# w
# s
# .
# \
# n
# "
# "
# P
# i
# s
#
# l
# e
# t
#
# m
# e
#
# k
# n
# o
# w
#
# w
# h
# a
# t
#
# P
# h
# i
# l
#
# f
# i
# n
# d
# s
#
# o
# u
# t
#
# a
# s
# a
# p
# .
#
# T
# h
# x
# .
# \
# n
# "
# "
# B
# 5
# \
# n
# "
# "
# W
# h
# e
# n
#
# i
# s
#
# C
# h
# r
# i
# s
#
# S
# t
# e
# v
# e
# n
# s
#
# g
# o
# i
# n
# g
# ?
# \
# n
# -
# -
# -
# ,
# \
# n
# "
# "
# U
# s
# e
# f
# u
# l
#
# i
# n
# s
# i
# g
# h
# t
# .
#
# P
# l
# s
#
# c
# i
# r
# c
# u
# l
# a
# t
# e
# .
# \
# n
# "
# "
# I
#
# t
# h
# a
# n
# k
# e
# d
#
# P
# r
# i
# n
# c
# e
#
# S
# a
# u
# d
# ...
